# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

data = pd.read_csv("Thecleverprogrammer.csv")
print(data.head())
# Out:
#          Date  Views
# 0  01/06/2021   7831
# 1  02/06/2021   7798
# 2  03/06/2021   7401
# 3  04/06/2021   7054
# 4  05/06/2021   7973

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')
print(data.head())
# Out:
#         Date  Views
# 0 2021-06-01   7831
# 1 2021-06-02   7798
# 2 2021-06-03   7401
# 3 2021-06-04   7054
# 4 2021-06-05   7973

# %%
import seaborn as sns

sns.lineplot(data=data, x='Date', y='Views')
plt.show()

# %% [markdown]
# Our website traffic data is seasonal because the traffic on the website increases during the weekdays and decreases during the weekends. It is valuable to know if the dataset is seasonal or not while working on the problem of Time Series Forecasting. Below is how we can have a look at whether our dataset is stationary or seasonal:

# %%
result = seasonal_decompose(data["Views"],
                            model='multiplicative',
                            period = 30)
fig = plt.figure()
fig = result.plot()
fig.set_size_inches(15, 10)

# %% [markdown]
# p = 5

# %%
pd.plotting.autocorrelation_plot(data["Views"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# q = 2 (2 anounymos alone points)

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data["Views"], lags = 100)

# %% [markdown]
# p, d, q = 5, 1(Seasonal), 2

# %%
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

p, d, q = 5, 1, 2
model=sm.tsa.statespace.SARIMAX(data['Views'],
                                order=(p, d, q),
                                seasonal_order=(p, d, q, 12))
model=model.fit()
print(model.summary())
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Views   No. Observations:                  391
# Model:             SARIMAX(5, 1, 2)x(5, 1, 2, 12)   Log Likelihood               -3098.936
# Date:                            Tue, 11 Mar 2025   AIC                           6227.873
# Time:                                    13:41:41   BIC                           6286.896
# Sample:                                         0   HQIC                          6251.298
#                                             - 391
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7687      0.129      5.953      0.000       0.516       1.022
# ar.L2         -0.8007      0.135     -5.922      0.000      -1.066      -0.536
# ar.L3         -0.1261      0.172     -0.731      0.465      -0.464       0.212
# ar.L4         -0.2135      0.153     -1.398      0.162      -0.513       0.086
# ar.L5         -0.1434      0.136     -1.052      0.293      -0.411       0.124
# ma.L1         -1.1894      0.083    -14.375      0.000      -1.352      -1.027
# ma.L2          0.9029      0.071     12.716      0.000       0.764       1.042
# ar.S.L12      -0.2442      3.947     -0.062      0.951      -7.979       7.491
# ar.S.L24       0.0708      0.480      0.147      0.883      -0.871       1.013
# ar.S.L36      -0.1763      0.306     -0.577      0.564      -0.775       0.423
# ar.S.L48      -0.2031      0.795     -0.256      0.798      -1.761       1.355
# ar.S.L60       0.0132      0.784      0.017      0.987      -1.524       1.551
# ma.S.L12      -0.6953      3.947     -0.176      0.860      -8.432       7.041
# ma.S.L24      -0.1325      3.274     -0.040      0.968      -6.549       6.284
# sigma2      1.257e+06   1.51e-05   8.34e+10      0.000    1.26e+06    1.26e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):                 0.85
# Prob(Q):                              0.76   Prob(JB):                         0.65
# Heteroskedasticity (H):               1.06   Skew:                             0.12
# Prob(H) (two-sided):                  0.74   Kurtosis:                         2.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.1e+27. Standard errors may be unstable.

# %%
predictions = model.predict(len(data), len(data)+50)
print(predictions)
# Out:
# 391     9929.396286
# 392    10832.401683
# 393    10707.034126
# 394     9811.460375
# 395     8751.363257
# 396     8247.813883
# 397     8975.861035
# 398     9771.074082
# 399    10327.223405
# 400    10583.354048
# 401     9866.967279
# 402     9302.448014
# 403     9004.661607
# 404     9115.025870
# 405    10557.655644
# 406    11042.368748
# 407    10931.788634
# 408    10059.743461
# 409     9375.433350
# 410     8615.795977
# 411     9237.781936
# 412    10411.470047
# 413    10694.701336
# 414    10811.651113
# 415    10221.743484
# 416     9358.209740
# 417     8937.925664
# 418     9190.105670
# 419     9988.381124
# 420    10313.744200
# 421    10742.878221
# 422     9860.265300
# 423     9448.485062
# 424     8958.563020
# 425     8919.589735
# 426    10277.095800
# 427    10956.517306
# 428    10922.462035
# 429    10317.235571
# 430     9358.715529
# 431     8684.788228
# 432     8792.123954
# 433    10188.611781
# 434    10633.501423
# 435    10895.437208
# 436    10376.878791
# 437     9261.809775
# 438     9156.138793
# 439     9435.494309
# 440    10419.843463
# 441    11239.103716
# Name: predicted_mean, dtype: float64

# %%
data["Views"].plot(legend=True, label="Training Data",
                   figsize=(15, 10))
predictions.plot(legend=True, label="Predictions")
# Out:
# <Axes: >
